# %% [markdown]
# ***Categorical to numerical***
#
# - It is very important convert categorical data to numerical data
# - Because in machine learning models the input is in the form of numbers
# - ML models developed by maths, so passing text data is not works
# - We have different types of methods are there
#
#    - map method
#    - np.where
#    - One hot encoder
#    - Label encoder

# %% [markdown]
# ***Read the packages***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ***Read the data***

# %%
visa_df=pd.read_csv("C:\\Users\\LENOVO\\OneDrive\\DATA SCIENCE\\data files\\Visadataset - Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.select_dtypes(include="object").columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %% [markdown]
# ***Map***
#
# - first get the unique labels for each column
# - create a dictionary by providing a values to each label
# - For example case status has two labels, we are providing two values
#    - Assign 0 for certified
#    - Assign 1 for Denied

# %%
visa_df["case_status"].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
d={"Denied":1,"Certified":0}
d
# Out:
# {'Denied': 1, 'Certified': 0}

# %%
visa_df["case_status"].map(d)
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 25475    0
# 25476    0
# 25477    0
# 25478    0
# 25479    0
# Name: case_status, Length: 25480, dtype: int64

# %%
visa_df["case_status_new"]=visa_df["case_status"].map(d)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
#if NAN is come u need to read the data again

# %%
visa_df=pd.read_csv("C:\\Users\\LENOVO\\OneDrive\\DATA SCIENCE\\data files\\Visadataset - Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
d1={"Y":1,"N":0}
d1
# Out:
# {'Y': 1, 'N': 0}

# %%
visa_df["has_job_experience"]=visa_df["has_job_experience"].map(d1)

# %%
visa_df
# Out:
#          case_id continent education_of_employee  has_job_experience  \
# 0         EZYV01      Asia           High School                   0
# 1         EZYV02      Asia              Master's                   1
# 2         EZYV03      Asia            Bachelor's                   0
# 3         EZYV04      Asia            Bachelor's                   0
# 4         EZYV05    Africa              Master's                   1
# ...          ...       ...                   ...                 ...
# 25475  EZYV25476      Asia            Bachelor's                   1
# 25476  EZYV25477      Asia           High School                   1
# 25477  EZYV25478      Asia              Master's                   1
# 25478  EZYV25479      Asia              Master's                   1
# 25479  EZYV25480      Asia            Bachelor's                   1
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
labels=list(visa_df["case_status"].unique())
values=[i for i in range(len(labels))]
dict(zip(labels,values))
# Out:
# {'Denied': 0, 'Certified': 1}

# %%
visa_df=pd.read_csv("C:\\Users\\LENOVO\\OneDrive\\DATA SCIENCE\\data files\\Visadataset - Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cols=visa_df.select_dtypes(include="object").columns
for i in cols:
        labels=list(visa_df[i].unique())
        values=[i for i in range(len(labels))]
        d=dict(zip(labels,values))
        visa_df[i]=visa_df[i].map(d)
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          0                      0                   0
# 1            1          0                      1                   1
# 2            2          0                      2                   0
# 3            3          0                      2                   0
# 4            4          1                      1                   1
# ...        ...        ...                    ...                 ...
# 25475    25475          0                      2                   1
# 25476    25476          0                      0                   1
# 25477    25477          0                      1                   1
# 25478    25478          0                      1                   1
# 25479    25479          0                      2                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %% [markdown]
# ***Label encoder***
#
# - It is a package under ***sickit learn***
# - Sickit-learn is heart of machine learning
# - In side sickit-learn we have a method called **Preprocessing**
# - Under preprocessing we have **LableEncoder**
# - scikit-learn we will write as **sklearn**
# - any sklearn package we have 3 steps
#    - step-1: Read the package
#    - step-2: Save the package
#    - step-3: Apply Fit transform

# %%
#read the data
visa_df=pd.read_csv("C:\\Users\\LENOVO\\OneDrive\\DATA SCIENCE\\data files\\Visadataset - Visadataset.csv")

# %%
#step-1:read the package
from sklearn.preprocessing import LabelEncoder
#step-2:save the package
le=LabelEncoder()
#step-3:apply fit ransfrom
visa_df["case_status"]=le.fit_transform(visa_df["case_status"])

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df=pd.read_csv("C:\\Users\\LENOVO\\OneDrive\\DATA SCIENCE\\data files\\Visadataset - Visadataset.csv")

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
visa_df["continent"]=le.fit_transform(visa_df["continent"])

# %%
visa_df
# Out:
#          case_id  continent education_of_employee has_job_experience  \
# 0         EZYV01          1           High School                  N
# 1         EZYV02          1              Master's                  Y
# 2         EZYV03          1            Bachelor's                  N
# 3         EZYV04          1            Bachelor's                  N
# 4         EZYV05          0              Master's                  Y
# ...          ...        ...                   ...                ...
# 25475  EZYV25476          1            Bachelor's                  Y
# 25476  EZYV25477          1           High School                  Y
# 25477  EZYV25478          1              Master's                  Y
# 25478  EZYV25479          1              Master's                  Y
# 25479  EZYV25480          1            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df=pd.read_csv("C:\\Users\\LENOVO\\OneDrive\\DATA SCIENCE\\data files\\Visadataset - Visadataset.csv")

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
cols=visa_df.select_dtypes(include="object").columns
for i in cols:
   
    visa_df[i]=le.fit_transform(visa_df[i])
        
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          1                      2                   0
# 1            1          1                      3                   1
# 2            2          1                      0                   0
# 3            3          1                      0                   0
# 4            4          0                      3                   1
# ...        ...        ...                    ...                 ...
# 25475    17204          1                      0                   1
# 25476    17205          1                      2                   1
# 25477    17206          1                      3                   1
# 25478    17207          1                      3                   1
# 25479    17209          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %%
visa_df=pd.read_csv("C:\\Users\\LENOVO\\OneDrive\\DATA SCIENCE\\data files\\Visadataset - Visadataset.csv")

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
visa_df["case_status"]=le.fit_transform(visa_df["case_status"])
print(visa_df["case_status"].values)       #why we are applying values
print(le.inverse_transform(visa_df["case_status"]))
# Out:
# [1 0 1 ... 0 0 0]
# ['Denied' 'Certified' 'Denied' ... 'Certified' 'Certified' 'Certified']

# %% [markdown]
# ***LabelEncoder will use most of the time***

# %% [markdown]
# ***np.where***
#
# - It is only applicable for binary
# - It will take 3 arguments
#     - condition
#     - True value
#     - False value

# %% [markdown]
# $Scenario$
#
# - For example case status value equal to certified then replace with zero
# - Otherwise replace with 1

# %%
visa_df=pd.read_csv("C:\\Users\\LENOVO\\OneDrive\\DATA SCIENCE\\data files\\Visadataset - Visadataset.csv")

# %%
con=(visa_df["case_status"]=="Certified")
visa_df["case_status"]=np.where(con,0,1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# ***One hot encoder***
# - One hot means if one is ON another one is OFF
# - ON represents with 1,and OFF represents with 0
# - For example case status has 2 unique labels
#     - Denied
#     - Certified
# - If we apply one hot encoder on case status column it will create 2 extra columns
#      - case_status_Denied
#      - case_status_Certified

# %%
visa_df=pd.read_csv("C:\\Users\\LENOVO\\OneDrive\\DATA SCIENCE\\data files\\Visadataset - Visadataset.csv")

# %% [markdown]
# |case_status|case_status_denied|case_status_certified|
# |----------|--|--|
# |Denied|1|0|
# |Certified|0|1|

# %% [markdown]
# **Advantages**
# - In machine learning we have one important property is **Independent of variables**
# - Machine learning models expects variables are **independent each other**
# - One hot encoder creating new columns,the new columns are **independent each other**
# - Independent variables means both variables have **90 degrees phase shift**
# - 90 degrees phase shift also called as **perpendicular to each other**
# - perpendicular to each other means **orthogonal to each other**
# - orthogonal to each other means **independent to each other**

# %% [markdown]
# ***Disadvantages***
# - One hot encoder creates new columns equal to number of unique labels
# - If number of unique labels are increase new columns also increase
# - The more columns leads data is more
# - Then data is more the complexity will increase
# - The complexity increases the time complexity will increases
# - Computation increases more computation power required
# - Also time also increase
# - The entire process names as **curse of dimensionality**

# %% [markdown]
# **pd.get_dummies**

# %% [markdown]
# - Read the data again
# - choose one column
# - apply pd.get_dummies

# %%
visa_df=pd.read_csv("C:\\Users\\LENOVO\\OneDrive\\DATA SCIENCE\\data files\\Visadataset - Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
pd.get_dummies(visa_df["case_status"])
# Out:
#        Certified  Denied
# 0          False    True
# 1           True   False
# 2          False    True
# 3          False    True
# 4           True   False
# ...          ...     ...
# 25475       True   False
# 25476       True   False
# 25477       True   False
# 25478       True   False
# 25479       True   False
#
# [25480 rows x 2 columns]

# %%
pd.get_dummies(visa_df["case_status"],dtype=int)
# Out:
#        Certified  Denied
# 0              0       1
# 1              1       0
# 2              0       1
# 3              0       1
# 4              1       0
# ...          ...     ...
# 25475          1       0
# 25476          1       0
# 25477          1       0
# 25478          1       0
# 25479          1       0
#
# [25480 rows x 2 columns]

# %%
visa_df=pd.read_csv("C:\\Users\\LENOVO\\OneDrive\\DATA SCIENCE\\data files\\Visadataset - Visadataset.csv")

# %%
pd.get_dummies(visa_df,dtype=int)
# Out:
#        no_of_employees  yr_of_estab  prevailing_wage  case_id_EZYV01  \
# 0                14513         2007         592.2029               1
# 1                 2412         2002       83425.6500               0
# 2                44444         2008      122996.8600               0
# 3                   98         1897       83434.0300               0
# 4                 1082         2005      149907.3900               0
# ...                ...          ...              ...             ...
# 25475             2601         2008       77092.5700               0
# 25476             3274         2006      279174.7900               0
# 25477             1121         1910      146298.8500               0
# 25478             1918         1887       86154.7700               0
# 25479             3195         1960       70876.9100               0
#
#        case_id_EZYV02  case_id_EZYV03  case_id_EZYV04  case_id_EZYV05  \
# ...

# %% [markdown]
# ***Note***
# - Always drop the id column

# %%
visa_df=pd.read_csv("C:\\Users\\LENOVO\\OneDrive\\DATA SCIENCE\\data files\\Visadataset - Visadataset.csv")

# %%
visa_df.drop("case_id",axis=1,inplace=True)
visa_df
# Out:
#       continent education_of_employee has_job_experience  \
# 0          Asia           High School                  N
# 1          Asia              Master's                  Y
# 2          Asia            Bachelor's                  N
# 3          Asia            Bachelor's                  N
# 4        Africa              Master's                  Y
# ...         ...                   ...                ...
# 25475      Asia            Bachelor's                  Y
# 25476      Asia           High School                  Y
# 25477      Asia              Master's                  Y
# 25478      Asia              Master's                  Y
# 25479      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# ...

# %%
pd.get_dummies(visa_df,dtype=int)
# Out:
#        no_of_employees  yr_of_estab  prevailing_wage  continent_Africa  \
# 0                14513         2007         592.2029                 0
# 1                 2412         2002       83425.6500                 0
# 2                44444         2008      122996.8600                 0
# 3                   98         1897       83434.0300                 0
# 4                 1082         2005      149907.3900                 1
# ...                ...          ...              ...               ...
# 25475             2601         2008       77092.5700                 0
# 25476             3274         2006      279174.7900                 0
# 25477             1121         1910      146298.8500                 0
# 25478             1918         1887       86154.7700                 0
# 25479             3195         1960       70876.9100                 0
#
#        continent_Asia  continent_Europe  continent_North America  \
# ...

# %% [markdown]
# - Generally we will prefer LabelEncoder
# - One hot encoder when categorical data has less unique labels
