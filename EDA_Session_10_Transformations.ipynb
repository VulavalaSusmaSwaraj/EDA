# %% [markdown]
# ***Data Transformations***
# - Generally data has 3 types of distributions
#      - Normal distribution
#      - Positive skewed
#      - Negative skewed
# - All the maths concepts developed by assumption as Data follows normal distribution
# - Data skew happens because of many reasons,in that one reason is outliers
# - once we perform the outlier analysis then we can apply transformation method,if the data follows normality
# - We have some transformation methods mentioned below
#     - Log transformation
#     - Exponential transformation
#     - Reciprocal transformation
#     - Square root transformation
#     - Power transformation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# $step-1$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# $step-2$
#
# ***Read the data***

# %%
exp_data=np.random.exponential(size=10000)
exp_data
# Out:
# array([0.0830535 , 0.05567516, 0.20163778, ..., 1.03671232, 0.53374974,
#        0.07909788])

# %% [markdown]
# $step-3$
#
# ***plot the data***

# %%
plt.hist(exp_data,bins=20,label="Exponential")
plt.show()

# %%
norm_data=np.random.normal(size=10000)
norm_data
# Out:
# array([ 1.61337048,  1.18286645, -0.06198665, ..., -1.26796063,
#        -0.55954093, -0.26646102])

# %%
plt.hist(norm_data,bins=20,label="Normal")
plt.show()
#bins means intervals

# %% [markdown]
# ***Goal***
#
#
# **Convert exp_data to normal distribution**
# - bins=interval

# %% [markdown]
# $step-4$
#
# **Log transformation**
#
# - Log transformation means performing logarithm operations on original data
# - It is an approach to convert into normal disribution
# - Log means natural logarithm base=e

# %%
x=2
np.log(x)
# Out:
# 0.6931471805599453

# %%
log_data=np.log(exp_data)
log_data
# Out:
# array([-2.48827031, -2.88822122, -1.60128234, ...,  0.03605448,
#        -0.62782819, -2.53706915])

# %%
plt.hist(log_data,bins=20,label="logarithm")
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1).hist(exp_data,bins=30,label="Exponential")
plt.legend()
plt.subplot(1,2,2).hist(log_data,bins=30,label="Logarithm")
plt.legend()
plt.show()

# %% [markdown]
# ***Reciprocal Transformation***
# - Reciprocal will fail when values are low
# - For example x=0 then 1/0 fail

# %%
x=2
1/x
# Out:
# 0.5

# %%
reciprocal_data=np.reciprocal(exp_data)

# %%
plt.hist(reciprocal_data,bins=30,label="Reciprocal")
plt.legend()
plt.show()

# %% [markdown]
# ***Square root Transformation***

# %%
square_root_data=np.sqrt(exp_data)
plt.hist(square_root_data,bins=20,label="square root data")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.subplot(2,2,1).hist(exp_data,bins=30,label="Exponential")
plt.legend()
plt.subplot(2,2,2).hist(log_data,bins=30,label="Logarithm")
plt.legend()
plt.subplot(2,2,3).hist(reciprocal_data,bins=30,label="Reciprocal")
plt.legend()
plt.subplot(2,2,4).hist(square_root_data,bins=20,label="square root data")
plt.legend()
plt.show()

# %% [markdown]
# ***Power Transformations***
# - Box cox
# - ye-jhonson
# - It is under sklearn package

# %% [markdown]
#  <img title=" - Lean Sigma Corporation" loading="lazy" decoding="async" class="wp-image-3154 alignnone" src="https://www.leansigmacorporation.com/wp/wp-content/uploads/2016/01/Box-Cox-EQ1.png" alt="Box Cox EQ1" width="234" height="79">

# %%
from sklearn.preprocessing import PowerTransformer
power=PowerTransformer(method="yeo-johnson")
exp_data1=exp_data.reshape(-1,1)
data_trans1=power.fit_transform(exp_data1)
plt.hist(data_trans1)
# Out:
# (array([1110., 1260., 1238., 1420., 1437., 1296., 1112.,  785.,  303.,
#           39.]),
#  array([-1.76610839, -1.32551545, -0.88492252, -0.44432959, -0.00373666,
#          0.43685627,  0.8774492 ,  1.31804213,  1.75863506,  2.19922799,
#          2.63982092]),
#  <BarContainer object of 10 artists>)

# %%
from sklearn.preprocessing import PowerTransformer
power=PowerTransformer(method="box-cox")
exp_data1=exp_data.reshape(-1,1)
data_trans2=power.fit_transform(exp_data1)
plt.hist(data_trans2)
# Out:
# (array([  53.,  394., 1062., 1987., 2633., 2167., 1236.,  408.,   55.,
#            5.]),
#  array([-3.09085264, -2.41222806, -1.73360349, -1.05497891, -0.37635434,
#          0.30227024,  0.98089481,  1.65951938,  2.33814396,  3.01676853,
#          3.69539311]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,2,1).hist(data_trans1,bins=20,label="Yeo-Johnson")
plt.legend()
plt.subplot(1,2,2).hist(data_trans2,bins=20,label="Box-cox")
plt.legend()
plt.show()
